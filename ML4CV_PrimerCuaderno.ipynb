# %% [markdown]
# <a href="https://colab.research.google.com/github/rubenchov/aprendizajeautomaticovision/blob/main/ML4CV_PrimerCuaderno.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hola mundo')
# Out:
# Hola mundo
